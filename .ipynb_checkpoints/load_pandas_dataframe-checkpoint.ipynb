# %%
import numpy as np
import pandas as pd
import tensorflow as tf

SHUFFLE_BUFFER = 500
BATCH_SIZE = 2
# Out:
# 2026-01-25 22:28:53.767692: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-25 22:28:53.794760: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-25 22:28:54.340305: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
csv_file = tf.keras.utils.get_file('heart.csv', 'https://storage.googleapis.com/download.tensorflow.org/data/heart.csv')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/heart.csv
# 13273/13273 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
target = df.pop('target')

# %%
numeric_feature_names = ['age', 'thalach', 'trestbps',  'chol', 'oldpeak']
numeric_features = df[numeric_feature_names]
numeric_features.head()
# Out:
#    age  thalach  trestbps  chol  oldpeak
# 0   63      150       145   233      2.3
# 1   67      108       160   286      1.5
# 2   67      129       120   229      2.6
# 3   37      187       130   250      3.5
# 4   41      172       130   204      1.4

# %%
tf.convert_to_tensor(numeric_features)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769398190.188307  102156 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1111 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# <tf.Tensor: shape=(303, 5), dtype=float64, numpy=
# array([[ 63. , 150. , 145. , 233. ,   2.3],
#        [ 67. , 108. , 160. , 286. ,   1.5],
#        [ 67. , 129. , 120. , 229. ,   2.6],
#        ...,
#        [ 65. , 127. , 135. , 254. ,   2.8],
#        [ 48. , 150. , 130. , 256. ,   0. ],
#        [ 63. , 154. , 150. , 407. ,   4. ]], shape=(303, 5))>

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(numeric_features))

# %%
normalizer(numeric_features.iloc[:3])
# Out:
# <tf.Tensor: shape=(3, 5), dtype=float32, numpy=
# array([[ 0.93384   ,  0.03480783,  0.74578166, -0.26008663,  1.0680454 ],
#        [ 1.3782114 , -1.7806157 ,  1.5923294 ,  0.75738776,  0.3802287 ],
#        [ 1.3782114 , -0.87290394, -0.6651312 , -0.33687717,  1.3259766 ]],
#       dtype=float32)>

# %%
def get_basic_model():
  model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
  ])

  model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
  return model

# %%
model = get_basic_model()
model.fit(numeric_features, target, epochs=15, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/15
# 2026-01-25 22:30:13.631366: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f8d64016990 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-25 22:30:13.631382: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2026-01-25 22:30:13.653972: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-25 22:30:13.744177: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 147/152 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.7459 - loss: 0.6601
# I0000 00:00:1769398214.037520  102415 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7228 - loss: 0.6439
# Epoch 2/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.7228 - loss: 0.5552
# Epoch 3/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.7327 - loss: 0.5058
# Epoch 4/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.7591 - loss: 0.4721
# Epoch 5/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.7954 - loss: 0.4545
# Epoch 6/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.7921 - loss: 0.4449
# Epoch 7/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.7921 - loss: 0.4379
# Epoch 8/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.7855 - loss: 0.4326
# Epoch 9/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.7987 - loss: 0.4287
# Epoch 10/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.7954 - loss: 0.4240
# Epoch 11/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7888 - loss: 0.4225
# Epoch 12/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.7921 - loss: 0.4186
# Epoch 13/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8020 - loss: 0.4170
# Epoch 14/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.8053 - loss: 0.4151
# Epoch 15/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.7888 - loss: 0.4138

# %%
numeric_dataset = tf.data.Dataset.from_tensor_slices((numeric_features, target))

for row in numeric_dataset.take(3):
  print(row)
# Out:
# (<tf.Tensor: shape=(5,), dtype=float64, numpy=array([ 63. , 150. , 145. , 233. ,   2.3])>, <tf.Tensor: shape=(), dtype=int64, numpy=0>)
# (<tf.Tensor: shape=(5,), dtype=float64, numpy=array([ 67. , 108. , 160. , 286. ,   1.5])>, <tf.Tensor: shape=(), dtype=int64, numpy=1>)
# (<tf.Tensor: shape=(5,), dtype=float64, numpy=array([ 67. , 129. , 120. , 229. ,   2.6])>, <tf.Tensor: shape=(), dtype=int64, numpy=0>)
# 2026-01-25 22:30:25.648601: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
numeric_batches = numeric_dataset.shuffle(1000).batch(BATCH_SIZE)

model = get_basic_model()
model.fit(numeric_batches, epochs=15)
# Out:
# Epoch 1/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7261 - loss: 0.6540
# Epoch 2/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.7558 - loss: 0.5293
# Epoch 3/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7624 - loss: 0.4713
# Epoch 4/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.7756 - loss: 0.4484
# Epoch 5/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.7954 - loss: 0.4365
# Epoch 6/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7987 - loss: 0.4304
# Epoch 7/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8119 - loss: 0.4264
# Epoch 8/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7954 - loss: 0.4245
# Epoch 9/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.8020 - loss: 0.4216
# Epoch 10/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.8119 - loss: 0.4193
# Epoch 11/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.8086 - loss: 0.4187
# Epoch 12/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.8053 - loss: 0.4151
# Epoch 13/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.8086 - loss: 0.4149
# Epoch 14/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.8086 - loss: 0.4134
# Epoch 15/15
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.8053 - loss: 0.4128
